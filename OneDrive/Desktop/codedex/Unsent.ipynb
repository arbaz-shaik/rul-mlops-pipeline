# %%
sent_message= "hey, i am in love with you"
with open("C:\\Users\\arbaz\\OneDrive\\Desktop\\codedex\\filer.txt", "w") as file:
    file.write(sent_message)

# %%
with open("C:\\Users\\arbaz\\OneDrive\\Desktop\\codedex\\filer.txt", "r+") as file:
    file.seek(2)
    file.truncate(4)
    data = file.read()
    print(data)
# Out:
# y,
